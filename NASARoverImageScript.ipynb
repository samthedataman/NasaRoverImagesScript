# %%
#Import Packages
import requests as r
import pandas as pd
import urllib.request
from IPython.display import Image
from IPython.display import Image, display

#Define Functions for list and dictionary conversions
def Convert(a):
 it = iter(a)
 res_dct = dict(zip(it,it))
 return res_dct

def getList(dict):
      
    return [*dict]


#Front Facing  Hazard Camera  Data Request from Curioisty Rover
FHAZ = r.get("https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos?sol=1000&camera=FHAZ&api_key=t7eJwYfUxcrUzIaI2HhdE1G12cSF6kKaFlf1FncS")
FHAZ= FHAZ.json()
#Rear Facing  Hazard Camera  Data Request from Curioisty Rover
RHAZ = r.get("https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos?sol=1000&camera=RHAZ&api_key=t7eJwYfUxcrUzIaI2HhdE1G12cSF6kKaFlf1FncS")
RHAZ= RHAZ.json()
#Mast Facing  Hazard Camera Data Request from Curioisty Rover
MAST = r.get("https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos?sol=1000&camera=MAST&api_key=t7eJwYfUxcrUzIaI2HhdE1G12cSF6kKaFlf1FncS")
MAST= MAST.json()
#Panaramic Facing Hazard Camera  Data Request from Curioisty Rover
PANCAM = r.get("https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos?sol=1000&camera=PANCAM&api_key=t7eJwYfUxcrUzIaI2HhdE1G12cSF6kKaFlf1FncS")
PANCAM= PANCAM.json()

#Loop for each json documents, find photos Key, for each image image in Key append in a list, display list
hict = []
for i in FHAZ['photos']:
  hict.append(i['img_src'])
for i in RHAZ['photos']:
  hict.append(i['img_src'])
for i in MAST['photos']:
  hict.append(i['img_src'])
for i in PANCAM['photos']:
  hict.append(i['img_src'])
#for each photo in list display photo
for i in hict:
    display(Image(i))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in _repr_mimebundle_(self, include, exclude)
#    1242         if self.embed:
#    1243             mimetype = self._mimetype
# -> 1244             data, metadata = self._data_and_metadata(always_both=True)
#    1245             if metadata:
#    1246                 metadata = {mimetype: metadata}
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in _data_and_metadata(self, always_both)
#    1251     def _data_and_metadata(self, always_both=False):
# ...
